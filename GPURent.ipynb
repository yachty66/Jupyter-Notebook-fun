# %% [markdown]
# [Renting](https://vast.ai/console/create/) GPU
#
# ![Screen%20Shot%202022-04-04%20at%2011.01.26%20AM.png](attachment:Screen%20Shot%202022-04-04%20at%2011.01.26%20AM.png)

# %% [markdown]
# [Buying](https://www.ebay.com/itm/175212091061?chn=ps&norover=1&mkevt=1&mkrid=711-117182-37290-0&mkcid=2&itemid=175212091061&targetid=1530766779495&device=c&mktype=&googleloc=1013581&poi=&campaignid=15434804066&mkgroupid=130455207556&rlsatarget=pla-1530766779495&abcId=9300764&merchantid=6296724&gclid=CjwKCAjwrqqSBhBbEiwAlQeqGgoQE9DpZ6jtlfIV6kq8Yi6ejcspH3P84HRIthS8F_COz9Atm_KxoBoCG7QQAvD_BwE) GPU
#
# ![Screen%20Shot%202022-04-04%20at%2011.02.36%20AM.png](attachment:Screen%20Shot%202022-04-04%20at%2011.02.36%20AM.png)

# %% [markdown]
# ## Calculations without electricity costs

# %%
RTX3090PerHour = 0.357
PriceRTX3090 = 680
hoursTillBreakEven = PriceRTX3090/RTX3090PerHour 
daysTillBreakEven = hoursTillBreakEven/24
print(hoursTillBreakEven)
print(daysTillBreakEven)
# Out:
# 1904.7619047619048
# 79.36507936507937

# %% [markdown]
# ## Calculations with electricity costs
#
# **Electricity costs**
#
# switzerland = [21,2 kW/h](https://de.statista.com/statistik/daten/studie/329740/umfrage/haushaltstrompreis-in-der-schweiz/#:~:text=Durchschnittlicher%20Strompreis%20f%C3%BCr%20Haushalte%20in%20der%20Schweiz%20bis%202022&text=Im%20Jahr%202022%20bezahlen%20Haushaltsstromkunden,h%C3%B6her%20als%20im%20Jahr%20zuvor.)
#
# germany = [36,19 cent kW/h](https://www.check24.de/strom/strompreise/#:~:text=Der%20durchschnittliche%20Strompreis%20in%20Deutschland,%2C%20Netzentgelten%20sowie%20Energiebeschaffung%2F%20Vertrieb.)
#
# **kW/h for RTX3090**
#
# kW/h = [~800](https://www.reddit.com/r/buildapc/comments/iigo59/rtx_3090_power_consumption/)
#
# **Calculating costs for Germany**
#
# ![Screen%20Shot%202022-04-04%20at%2011.26.41%20AM.png](attachment:Screen%20Shot%202022-04-04%20at%2011.26.41%20AM.png)

# %% [markdown]
# ## Final results

# %%
costPerHour = 0.288
reveneuPerHour = 0.33
profitPerHour = reveneuPerHour - costPerHour
hoursTillBreakEven = PriceRTX3090 / profitPerHour
daysTillBreakEven = hoursTillBreakEven / 24

print("Profit per hour: " +  str(profitPerHour))
print("Days till break even : " + str(daysTillBreakEven))
# Out:
# Profit per hour: 0.04200000000000004
# Days till break even : 674.603174603174

# %%
## Summary

Bisher ist noch ungeklärt wie hoch die Ausnutzung ist für das vermieten auf Seiten wie vast.ai (warte auf Email). Aber bei konstanter Auslastung ist man nach 2 Jahren break even. Ich habe immer Minimalwerte genommen. Es gibt super viel Optimierungsraum (Land wo man Strom charged, GPU, Anbieter, gesamtes Geschäftsmodell). Bin down es auszuprobieren.

# %% [markdown]
# Helpful ressources:
#
#    [vast.ai](https://vast.ai/faq/)
